# %%
import matplotlib
import keras
import mtcnn

# %%
for imgi in index :
    for imgo in others:
        if imgi.name = imgo.name
            Put them in "same" directory
        else put them in "different" directory

# %%
import cv2
import os

def load_images_from_directory(image_directory):
    images = []
    for filename in os.listdir(image_directory):
        img = cv2.imread(os.path.join(image_directory,filename))
        
        if img is not None:
            images.append(img)
    return images
#folder="directory/folder path"

# %%
index_directory = 'dataset/dataset_internship/dataset/index'
others_directory = 'dataset/dataset_internship/dataset/others'

all_images = load_images_from_directory(index_directory)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

imshow(all_images[0])

# %%
import shutil


    
different_dir = './Untitled Folder/different'
if not os.path.exists(different_dir):
    os.makedirs(different_dir)

for i, index_name in enumerate(os.listdir(index_directory)):
    
    same_images = []
    #same_images.append(index_name)
    print(index_name)
    
    for j, others_name in enumerate(os.listdir(others_directory)): 
        
        #index_name_id = index_name[1]
        others_name_id, _ = others_name.split("_", 1)
        others_name_id = others_name_id + ".jpg"
        if (index_name == others_name_id) :
            print(index_name , " & ", others_name)
            same_images.append(others_name)
            if same_images :
                
                # Add index image to same_images list
                #same_images.append(index_name)
                
                # Create a directory for same images
                same_dir = './Untitled Folder/same' + i
                if not os.path.exists(same_dir):
                    os.makedirs(same_dir)
                    
                #print("same images " , same_images)
                shutil.move('dataset/dataset_internship/dataset/index/' + index_name , same_dir)
                for f in same_images :
                    shutil.move('dataset/dataset_internship/dataset/others/' + f , same_dir)
            else :
                shutil.move('dataset/dataset_internship/dataset/index/' + index_name , same_dir)
# Out:
# 1.jpg
# 10.jpg
# 100.jpg
# 1000.jpg
# 1002.jpg
# 1004.jpg
# 1005.jpg
# 1007.jpg
# 1008.jpg
# 1009.jpg
# 101.jpg
# 1010.jpg
# 1011.jpg
# 1011.jpg  &  1011_0001.jpg
# 1011.jpg  &  1011_0002.jpg
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-79-b3b476edd1d5> in <module>
#      32
#      33                 #print("same images " , same_images)
# ---> 34                 shutil.move('dataset/dataset_internship/dataset/index/' + index_name , same_dir)
#      35                 for f in same_images :
#      36                     shutil.move('dataset/dataset_internship/dataset/others/' + f , same_dir)
#
# ~\anaconda3\envs\tensorflow\lib\shutil.py in move(src, dst, copy_function)
#     562         real_dst = os.path.join(dst, _basename(src))
#     563         if os.path.exists(real_dst):
# ...

# %%
for others_name in enumerate(os.listdir(others_directory)):
    #for fname in file_list:
    #res = re.findall("ID_(\d+).pdf", fname)
    #if not res: continue
    #print res[0] # You can append the result to a list
    #print(others_name[1])
    others_name_id, _ = others_name[1].split("_", 1)
    others_name_id = others_name_id + ".jpg"
    if  (others_name_id == '44.jpg') :
        print(others_name_id)
       
        img.save('same/', 'JPEG')
# Out:
# 44.jpg
# 44.jpg
# 44.jpg
# 44.jpg

# %%
for index_name in enumerate(os.listdir(index_directory)):
    
    if  (index_name[1] == '44.jpg') :
        print(index_name[1])
# Out:
# 44.jpg

# %%
import shutil

    files = ['file1.txt', 'file2.txt', 'file3.txt']
    for f in files:
    shutil.move(f, 'dest_folder')
# Out:
# dataset/dataset_internship/dataset/index/

# %%
for f in os.listdir(index_directory) :
    print(f.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-d654cb2e3d5a> in <module>
#       1 for f in os.listdir(index_directory) :
# ----> 2     print(f.name)
#
# AttributeError: 'str' object has no attribute 'name'

# %%
import os
import shutil

index_directory = 'dataset/dataset_internship/dataset/index/2.jpg'
others_directory = 'dataset/dataset_internship/dataset/others/18_0001.jpg'

# Get index ID
index = index_directory.split("/")
index_id = index[-1]

# Get Others ID 
others = others_directory.split("/")
others_id = others[-1]
others_id, _ = others_id.split("_", 1)
others_id = others_id + ".jpg"

if (index_id == others_id) :
    
    # Create same directory
    same_dir = './Untitled Folder/same'
    if not os.path.exists(same_dir):
        os.makedirs(same_dir)
    # Move same images to same directory
    shutil.move(index_directory, same_dir)
    shutil.move(others_directory, same_dir)
    
else :
    
    # Create different directory
    different_dir = './Untitled Folder/different'
    if not os.path.exists(different_dir):
        os.makedirs(different_dir)
    # Move different images to different directory
    shutil.move(index_directory, different_dir)   
    shutil.move(others_directory, different_dir)
